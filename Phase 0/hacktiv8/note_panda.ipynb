# %%
# import
import pandas as pd

# loading data
# csv, excel, pdf, ppt, ...
df = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/teams.csv')

df
# Out:
#                       division         conference               school_name  \
# 0     FBS (Division I-A Teams)  American Athletic                Cincinnati
# 1     FBS (Division I-A Teams)  American Athletic               Connecticut
# 2     FBS (Division I-A Teams)  American Athletic                   Houston
# 3     FBS (Division I-A Teams)  American Athletic                Louisville
# 4     FBS (Division I-A Teams)  American Athletic                   Memphis
# ..                         ...                ...                       ...
# 247  FCS (Division I-AA Teams)               SWAC             Jackson State
# 248  FCS (Division I-AA Teams)               SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)               SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)               SWAC       Southern University
# 251  FCS (Division I-AA Teams)               SWAC            Texas Southern
#
# ...

# %%
df.head() # ambil sample sebanyak 5 data teratas
# Out:
#                    division         conference  school_name  \
# 0  FBS (Division I-A Teams)  American Athletic   Cincinnati
# 1  FBS (Division I-A Teams)  American Athletic  Connecticut
# 2  FBS (Division I-A Teams)  American Athletic      Houston
# 3  FBS (Division I-A Teams)  American Athletic   Louisville
# 4  FBS (Division I-A Teams)  American Athletic      Memphis
#
#                                         roster_url  id
# 0  http://espn.go.com/ncf/teams/roster?teamId=2132   1
# 1    http://espn.go.com/ncf/teams/roster?teamId=41   2
# 2   http://espn.go.com/ncf/teams/roster?teamId=248   3
# 3    http://espn.go.com/ncf/teams/roster?teamId=97   4
# 4   http://espn.go.com/ncf/teams/roster?teamId=235   5

# %%
df.tail() # ambil sample sebanyak 5 data terakhir

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   division     252 non-null    object
#  1   conference   252 non-null    object
#  2   school_name  252 non-null    object
#  3   roster_url   252 non-null    object
#  4   id           252 non-null    int64
# dtypes: int64(1), object(4)
# memory usage: 10.0+ KB

# %%
df.shape
# Out:
# (252, 5)

# %%
df.describe()
# Out:
#                id
# count  252.000000
# mean   126.500000
# std     72.890329
# min      1.000000
# 25%     63.750000
# 50%    126.500000
# 75%    189.250000
# max    252.000000

# %%
df.columns
# Out:
# Index(['division', 'conference', 'school_name', 'roster_url', 'id'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=252, step=1)

# %%
df.dtypes
# Out:
# division       object
# conference     object
# school_name    object
# roster_url     object
# id              int64
# dtype: object

# %%
df.nunique()
# Out:
# division         2
# conference      25
# school_name    252
# roster_url     252
# id             252
# dtype: int64

# %%
df.division.value_counts()
# Out:
# division
# FBS (Division I-A Teams)     126
# FCS (Division I-AA Teams)    126
# Name: count, dtype: int64

# %%
df.value_counts()
# Out:
# division                   conference        school_name        roster_url                                       id
# FBS (Division I-A Teams)   ACC               Boston College     http://espn.go.com/ncf/teams/roster?teamId=103   11     1
# FCS (Division I-AA Teams)  MEAC              Howard             http://espn.go.com/ncf/teams/roster?teamId=47    174    1
#                            FCS Independents  Monmouth           http://espn.go.com/ncf/teams/roster?teamId=2405  161    1
#                            Ivy               Brown              http://espn.go.com/ncf/teams/roster?teamId=225   162    1
#                                              Columbia           http://espn.go.com/ncf/teams/roster?teamId=171   163    1
#                                                                                                                        ..
# FBS (Division I-A Teams)   Mountain West     San Jose State     http://espn.go.com/ncf/teams/roster?teamId=23    89     1
# ...

# %%
df.isnull() # cek missing value
# Out:
#      division  conference  school_name  roster_url     id
# 0       False       False        False       False  False
# 1       False       False        False       False  False
# 2       False       False        False       False  False
# 3       False       False        False       False  False
# 4       False       False        False       False  False
# ..        ...         ...          ...         ...    ...
# 247     False       False        False       False  False
# 248     False       False        False       False  False
# 249     False       False        False       False  False
# 250     False       False        False       False  False
# 251     False       False        False       False  False
#
# [252 rows x 5 columns]

# %%
df
# Out:
#                       division         conference               school_name  \
# 0     FBS (Division I-A Teams)  American Athletic                Cincinnati
# 1     FBS (Division I-A Teams)  American Athletic               Connecticut
# 2     FBS (Division I-A Teams)  American Athletic                   Houston
# 3     FBS (Division I-A Teams)  American Athletic                Louisville
# 4     FBS (Division I-A Teams)  American Athletic                   Memphis
# ..                         ...                ...                       ...
# 247  FCS (Division I-AA Teams)               SWAC             Jackson State
# 248  FCS (Division I-AA Teams)               SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)               SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)               SWAC       Southern University
# 251  FCS (Division I-AA Teams)               SWAC            Texas Southern
#
# ...

# %%
df_sort = df.sort_values(by='school_name', ascending=False) # sort berdasarkan id -> default: asc

df_sort
# Out:
#                       division        conference        school_name  \
# 189  FCS (Division I-AA Teams)   Missouri Valley   Youngstown State
# 168  FCS (Division I-AA Teams)               Ivy               Yale
# 91    FBS (Division I-A Teams)     Mountain West            Wyoming
# 233  FCS (Division I-AA Teams)          Southern            Wofford
# 45    FBS (Division I-A Teams)           Big Ten          Wisconsin
# ..                         ...               ...                ...
# 242  FCS (Division I-AA Teams)              SWAC        Alabama A&M
# 104   FBS (Division I-A Teams)               SEC            Alabama
# 67    FBS (Division I-A Teams)      Mid-American              Akron
# 80    FBS (Division I-A Teams)     Mountain West          Air Force
# 156  FCS (Division I-AA Teams)  FCS Independents  Abilene Christian
#
#                                           roster_url   id
# 189  http://espn.go.com/ncf/teams/roster?teamId=2754  190
# ...

# %%
# square brackets
df['division']
# Out:
# 0       FBS (Division I-A Teams)
# 1       FBS (Division I-A Teams)
# 2       FBS (Division I-A Teams)
# 3       FBS (Division I-A Teams)
# 4       FBS (Division I-A Teams)
#                  ...
# 247    FCS (Division I-AA Teams)
# 248    FCS (Division I-AA Teams)
# 249    FCS (Division I-AA Teams)
# 250    FCS (Division I-AA Teams)
# 251    FCS (Division I-AA Teams)
# Name: division, Length: 252, dtype: object

# %%
# multiple column
new_df = df[["division", 'conference', 'id']]

new_df
# Out:
#                       division         conference   id
# 0     FBS (Division I-A Teams)  American Athletic    1
# 1     FBS (Division I-A Teams)  American Athletic    2
# 2     FBS (Division I-A Teams)  American Athletic    3
# 3     FBS (Division I-A Teams)  American Athletic    4
# 4     FBS (Division I-A Teams)  American Athletic    5
# ..                         ...                ...  ...
# 247  FCS (Division I-AA Teams)               SWAC  248
# 248  FCS (Division I-AA Teams)               SWAC  249
# 249  FCS (Division I-AA Teams)               SWAC  250
# 250  FCS (Division I-AA Teams)               SWAC  251
# 251  FCS (Division I-AA Teams)               SWAC  252
#
# [252 rows x 3 columns]

# %%
ls = [1,2,3,4,5]
ls[1:3]
# Out:
# [2, 3]

# %%
# access row .iloc[]
new_df.iloc[5:10]
# Out:
#                    division         conference  id
# 5  FBS (Division I-A Teams)  American Athletic   6
# 6  FBS (Division I-A Teams)  American Athletic   7
# 7  FBS (Division I-A Teams)  American Athletic   8
# 8  FBS (Division I-A Teams)  American Athletic   9
# 9  FBS (Division I-A Teams)  American Athletic  10

# %%
# mengubah index dataframe
new_df2 = df.set_index('school_name')

new_df2
# Out:
#                                            division         conference  \
# school_name
# Cincinnati                 FBS (Division I-A Teams)  American Athletic
# Connecticut                FBS (Division I-A Teams)  American Athletic
# Houston                    FBS (Division I-A Teams)  American Athletic
# Louisville                 FBS (Division I-A Teams)  American Athletic
# Memphis                    FBS (Division I-A Teams)  American Athletic
# ...                                             ...                ...
# Jackson State             FCS (Division I-AA Teams)               SWAC
# Mississippi Valley State  FCS (Division I-AA Teams)               SWAC
# Prairie View A&M          FCS (Division I-AA Teams)               SWAC
# Southern University       FCS (Division I-AA Teams)               SWAC
# Texas Southern            FCS (Division I-AA Teams)               SWAC
#
#                                                                roster_url   id
# school_name
# ...

# %%
# accessing row .loc[]
new_df2.loc['Connecticut':'Memphis']
# Out:
#                              division         conference  \
# school_name
# Connecticut  FBS (Division I-A Teams)  American Athletic
# Houston      FBS (Division I-A Teams)  American Athletic
# Louisville   FBS (Division I-A Teams)  American Athletic
# Memphis      FBS (Division I-A Teams)  American Athletic
#
#                                                  roster_url  id
# school_name
# Connecticut   http://espn.go.com/ncf/teams/roster?teamId=41   2
# Houston      http://espn.go.com/ncf/teams/roster?teamId=248   3
# Louisville    http://espn.go.com/ncf/teams/roster?teamId=97   4
# Memphis      http://espn.go.com/ncf/teams/roster?teamId=235   5

# %%
# dot notation
df.division
# Out:
# 0       FBS (Division I-A Teams)
# 1       FBS (Division I-A Teams)
# 2       FBS (Division I-A Teams)
# 3       FBS (Division I-A Teams)
# 4       FBS (Division I-A Teams)
#                  ...
# 247    FCS (Division I-AA Teams)
# 248    FCS (Division I-AA Teams)
# 249    FCS (Division I-AA Teams)
# 250    FCS (Division I-AA Teams)
# 251    FCS (Division I-AA Teams)
# Name: division, Length: 252, dtype: object

# %%
df.school_name.str.lower()
# Out:
# 0                    cincinnati
# 1                   connecticut
# 2                       houston
# 3                    louisville
# 4                       memphis
#                  ...
# 247               jackson state
# 248    mississippi valley state
# 249            prairie view a&m
# 250         southern university
# 251              texas southern
# Name: school_name, Length: 252, dtype: object

# %%
# filtering []
cond1 = df.conference == 'American Athletic'
cond2 = df.school_name.str.lower() == 'Memphis'.lower()
df[cond1 & cond2]
# Out:
#                    division         conference school_name  \
# 4  FBS (Division I-A Teams)  American Athletic     Memphis
#
#                                        roster_url  id
# 4  http://espn.go.com/ncf/teams/roster?teamId=235   5

# %%
# where school_name in ('Cincinnati', 'Rutgers', 'Temple')
df[df.school_name.isin(['Cincinnati', 'Rutgers', 'Temple'])]
# Out:
#                    division         conference school_name  \
# 0  FBS (Division I-A Teams)  American Athletic  Cincinnati
# 5  FBS (Division I-A Teams)  American Athletic     Rutgers
# 8  FBS (Division I-A Teams)  American Athletic      Temple
#
#                                         roster_url  id
# 0  http://espn.go.com/ncf/teams/roster?teamId=2132   1
# 5   http://espn.go.com/ncf/teams/roster?teamId=164   6
# 8   http://espn.go.com/ncf/teams/roster?teamId=218   9

# %%
df.loc[df.conference == 'American Athletic', 'school_name']
# Out:
# 0            Cincinnati
# 1           Connecticut
# 2               Houston
# 3            Louisville
# 4               Memphis
# 5               Rutgers
# 6         South Florida
# 7    Southern Methodist
# 8                Temple
# 9                   UCF
# Name: school_name, dtype: object

# %%
# where school_name like '%ford%'
df[df['school_name'].str.contains('ford')]
# Out:
#                       division conference school_name  \
# 98    FBS (Division I-A Teams)     Pac-12    Stanford
# 231  FCS (Division I-AA Teams)   Southern     Samford
# 233  FCS (Division I-AA Teams)   Southern     Wofford
#
#                                           roster_url   id
# 98     http://espn.go.com/ncf/teams/roster?teamId=24   99
# 231  http://espn.go.com/ncf/teams/roster?teamId=2535  232
# 233  http://espn.go.com/ncf/teams/roster?teamId=2747  234

# %%
# where name = 'xxx' and age = 123
df.query("conference == 'American Athletic' and school_name == 'Memphis'")
# Out:
#                    division         conference school_name  \
# 4  FBS (Division I-A Teams)  American Athletic     Memphis
#
#                                        roster_url  id
# 4  http://espn.go.com/ncf/teams/roster?teamId=235   5

# %%
df
# Out:
#                       division         conference               school_name  \
# 0     FBS (Division I-A Teams)  American Athletic                Cincinnati
# 1     FBS (Division I-A Teams)  American Athletic               Connecticut
# 2     FBS (Division I-A Teams)  American Athletic                   Houston
# 3     FBS (Division I-A Teams)  American Athletic                Louisville
# 4     FBS (Division I-A Teams)  American Athletic                   Memphis
# ..                         ...                ...                       ...
# 247  FCS (Division I-AA Teams)               SWAC             Jackson State
# 248  FCS (Division I-AA Teams)               SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)               SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)               SWAC       Southern University
# 251  FCS (Division I-AA Teams)               SWAC            Texas Southern
#
# ...

# %%
# add new column with values
df['new_column'] = df.id + 100
# Out:
# /var/folders/bz/6104vjk13md__qg_71ltbgvr0000gn/T/ipykernel_43798/1356076065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['new_column'] = df.id + 100

# %%
df
# Out:
#                       division         conference               school_name  \
# 0     FBS (Division I-A Teams)  American Athletic                Cincinnati
# 1     FBS (Division I-A Teams)  American Athletic               Connecticut
# 2     FBS (Division I-A Teams)  American Athletic                   Houston
# 3     FBS (Division I-A Teams)  American Athletic                Louisville
# 5     FBS (Division I-A Teams)  American Athletic                   Rutgers
# ..                         ...                ...                       ...
# 246  FCS (Division I-AA Teams)               SWAC           Grambling State
# 248  FCS (Division I-AA Teams)               SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)               SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)               SWAC       Southern University
# 251  FCS (Division I-AA Teams)               SWAC            Texas Southern
#
#       id  new_column
# 0      1         101
# ...

# %%
new_row = {
    "division": "One",
    "conference": "Meja Bundar",
    "school_name":"Binus",
    "roster_url":"www.google.com",
    "id":999,
    "new_column":"abc"
}

# add new row
df._append(new_row, ignore_index=True)
# Out:
#                       division         conference               school_name  \
# 0     FBS (Division I-A Teams)  American Athletic                Cincinnati
# 1     FBS (Division I-A Teams)  American Athletic               Connecticut
# 2     FBS (Division I-A Teams)  American Athletic                   Houston
# 3     FBS (Division I-A Teams)  American Athletic                Louisville
# 4     FBS (Division I-A Teams)  American Athletic                   Memphis
# ..                         ...                ...                       ...
# 248  FCS (Division I-AA Teams)               SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)               SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)               SWAC       Southern University
# 251  FCS (Division I-AA Teams)               SWAC            Texas Southern
# 252                        One        Meja Bundar                     Binus
#
# ...

# %%
df
# Out:
#                       division         conference               school_name  \
# 0     FBS (Division I-A Teams)  American Athletic                Cincinnati
# 1     FBS (Division I-A Teams)  American Athletic               Connecticut
# 2     FBS (Division I-A Teams)  American Athletic                   Houston
# 3     FBS (Division I-A Teams)  American Athletic                Louisville
# 5     FBS (Division I-A Teams)  American Athletic                   Rutgers
# ..                         ...                ...                       ...
# 246  FCS (Division I-AA Teams)               SWAC           Grambling State
# 248  FCS (Division I-AA Teams)               SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)               SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)               SWAC       Southern University
# 251  FCS (Division I-AA Teams)               SWAC            Texas Southern
#
#       id new_column
# 0      1
# 1      2
# 2      3
# ...

# %%
# remove column
df_backup = df
df.drop('new_column', axis=1, inplace=True)
# Out:
#                       division         conference               school_name  \
# 0     FBS (Division I-A Teams)  American Athletic                Cincinnati
# 1     FBS (Division I-A Teams)  American Athletic               Connecticut
# 2     FBS (Division I-A Teams)  American Athletic                   Houston
# 3     FBS (Division I-A Teams)  American Athletic                Louisville
# 4     FBS (Division I-A Teams)  American Athletic                   Memphis
# ..                         ...                ...                       ...
# 247  FCS (Division I-AA Teams)               SWAC             Jackson State
# 248  FCS (Division I-AA Teams)               SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)               SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)               SWAC       Southern University
# 251  FCS (Division I-AA Teams)               SWAC            Texas Southern
#
# ...

# %%
# keyword: del
del df['roster_url']

# %%
# remove row
df.drop(247, inplace=True)

# %%
# boolean indexing / filtering untuk exclude data
df = df[df.school_name != 'Memphis']

# %%
df
# Out:
#                       division         conference               school_name  \
# 0     FBS (Division I-A Teams)  American Athletic                Cincinnati
# 1     FBS (Division I-A Teams)  American Athletic               Connecticut
# 2     FBS (Division I-A Teams)  American Athletic                   Houston
# 3     FBS (Division I-A Teams)  American Athletic                Louisville
# 5     FBS (Division I-A Teams)  American Athletic                   Rutgers
# ..                         ...                ...                       ...
# 246  FCS (Division I-AA Teams)               SWAC           Grambling State
# 248  FCS (Division I-AA Teams)               SWAC  Mississippi Valley State
# 249  FCS (Division I-AA Teams)               SWAC          Prairie View A&M
# 250  FCS (Division I-AA Teams)               SWAC       Southern University
# 251  FCS (Division I-AA Teams)               SWAC            Texas Southern
#
#       id new_column
# 0      1
# 1      2
# 2      3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 250 entries, 0 to 251
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   division     250 non-null    object
#  1   conference   250 non-null    object
#  2   school_name  250 non-null    object
#  3   id           250 non-null    int64
#  4   new_column   250 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 11.7+ KB

# %%
df['new_column'].mean()
# Out:
# 226.5

# %%
df.agg({
    "id": "sum",
    "new_column": "mean"
})
# Out:
# id            31625.0
# new_column      226.5
# dtype: float64

# %%
# select division, conference, avg(new_column)
# from ...
# group by division, conference
dfbaru = df.groupby(['division', 'conference'])
dfbaru['new_column'].mean()
# Out:
# division                   conference
# FBS (Division I-A Teams)   ACC                  117.500000
#                            American Athletic    105.555556
#                            Big 12               129.500000
#                            Big Ten              140.500000
#                            Conference USA       153.500000
#                            FBS Independents     164.000000
#                            Mid-American         174.000000
#                            Mountain West        186.500000
#                            Pac-12               198.500000
#                            SEC                  211.500000
#                            Sun Belt             222.500000
# FCS (Division I-AA Teams)  Big Sky              233.000000
#                            Big South            242.500000
#                            CAA                  251.000000
#                            FCS Independents     259.000000
# ...
